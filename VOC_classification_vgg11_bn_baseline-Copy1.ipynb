# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch, os, numpy as np
import torch.optim as optim
import torch.nn as nn
import cv2 
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from tensorboardX import SummaryWriter
import math

os.environ["CUDA_VISIBLE_DEVICES"]="1"
Device=torch.cuda.current_device()
torch.cuda.empty_cache()

from loader_weakly_image import VOC2012_Aug_Image_caffe

# %%
##############################################################
exper_name = 'ImageBCE_trainvalset'
batch_size = 10
EPOCH = 30
steps = [15,30,45]
gamma = 0.1
#lr = 1e-2
weight_decay = 5e-4
##############################################################
root= './VOCdevkit/VOC2012/ImageSets/Main/'
trainset = VOC2012_Aug_Image_caffe(root = root, mode='train', dataaug=True,
                                   size=(256, 256), scales=(0.75, 1., 1.25, 1.5, 1.75, 2.))

valset = VOC2012_Aug_Image_caffe(root = root, mode='val', dataaug=True,
                                   size=(256, 256), scales=(0.75, 1., 1.25, 1.5, 1.75, 2.))


print(len(trainset))
print(len(valset))
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(valset, batch_size=batch_size, shuffle=True, num_workers=4)
# Out:
# 5717
# 5823

# %%
class VGG(nn.Module):
    def __init__(self, features, num_classes=20):
        super(VGG, self).__init__()
        self.features = features
        self.classifier = nn.Sequential(
            nn.Linear(8*8*512, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, num_classes),
        )
        self._initialize_weights()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        x = self.sigmoid(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()


def make_layers(cfg, batch_norm=False):
    layers = []
    in_channels = 3
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        elif v == 'A':
            layers += []
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)


cfg = {
    'A': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'B': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'D': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 'A',512, 512, 512, 'M','A', 512, 512, 512, 'M'],
    'E': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}


def vgg11_bn(pretrained=False, **kwargs):
    
    model = VGG(make_layers(cfg['A'], batch_norm=True), **kwargs)
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['vgg16_bn']))
    return model

# %%
model = vgg11_bn()
model.to(Device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(inplace=True)
#     (28): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=20, bias=True)
#   )
#   (sigmoid): Sigmoid()
# )

# %%
params = model.parameters()
optimizer = torch.optim.SGD(params, lr= 0.1)
#optimizer =torch.optim.Adagrad(params, lr=0.01, lr_decay=0)
criterion = nn.BCELoss(reduction='mean')

# %%
def get_accuracy(pred, target):
    acc = (pred==target)*1.0
    acc = torch.sum(acc, 1).float()
    acc = (acc- acc%20) / 20
    acc = torch.sum(acc) / 10
    return acc

def get_prediction(output):
    return torch.round(output)

# %%
EPOCH = 100
writer = SummaryWriter()
test_acc = []
for ep in range(1, EPOCH+1):
    test_count = 0
    accuracy = 0 
    acc = 0
    it_count = 0
    model.train()
    for it, (img, target) in enumerate(train_loader):
        
        img = img.to(Device)
        target = target.to(Device)

        optimizer.zero_grad()
        pred = model(img)
        loss = criterion(pred, target)
        loss.backward()
        optimizer.step()
        average_loss =  loss.item() 
        
        if it%100==0:
            pred = get_prediction(pred)
            acc += get_accuracy(pred, target)
            print('EPOCH : {:03d}/{:3d} | Loss : {:.4f}, training_accuracy: {:.4f}'.format(ep, EPOCH, average_loss, acc/(it_count+1)))
            #writer.add_scalars('training_loss', average_loss , it_count)
            it_count +=1
    
    #for it, (img, target)  in enumerate(val_loader):
    #    img = img.to(Device)
    #    target = target.to(Device)
    #    pred = model(img)
    #    pred = get_prediction(pred)
    #    accuracy += get_accuracy(pred, target)
    #    test_count += 1
    #accuracy /= test_count
    #test_acc.append(accuracy)
    #print('Test accuracy : {:.4f}'.format(accuracy))
    if (ep+1) == EPOCH:
        torch.save(model.state_dict(), './weights/Baseline_{}_{}.pt'.format(exper_name, ep))
# Out:
# EPOCH : 001/100 | Loss : 0.8204, training_accuracy: 0.0000
# EPOCH : 001/100 | Loss : 0.2486, training_accuracy: 0.0000
# EPOCH : 001/100 | Loss : 0.1979, training_accuracy: 0.0333
# EPOCH : 001/100 | Loss : 0.2652, training_accuracy: 0.0250
# EPOCH : 001/100 | Loss : 0.1834, training_accuracy: 0.0400
# EPOCH : 001/100 | Loss : 0.3444, training_accuracy: 0.0333
# EPOCH : 002/100 | Loss : 0.2638, training_accuracy: 0.0000
# EPOCH : 002/100 | Loss : 0.2415, training_accuracy: 0.0000
# EPOCH : 002/100 | Loss : 0.2565, training_accuracy: 0.0000
# EPOCH : 002/100 | Loss : 0.2577, training_accuracy: 0.0000
# EPOCH : 002/100 | Loss : 0.2242, training_accuracy: 0.0000
# EPOCH : 002/100 | Loss : 0.2043, training_accuracy: 0.0167
# EPOCH : 003/100 | Loss : 0.2486, training_accuracy: 0.1000
# EPOCH : 003/100 | Loss : 0.2421, training_accuracy: 0.1000
# EPOCH : 003/100 | Loss : 0.1912, training_accuracy: 0.1333
# EPOCH : 003/100 | Loss : 0.2134, training_accuracy: 0.1250
# EPOCH : 003/100 | Loss : 0.2473, training_accuracy: 0.1200
# EPOCH : 003/100 | Loss : 0.2040, training_accuracy: 0.1167
# EPOCH : 004/100 | Loss : 0.2125, training_accuracy: 0.0000
# EPOCH : 004/100 | Loss : 0.2075, training_accuracy: 0.0500
# EPOCH : 004/100 | Loss : 0.2159, training_accuracy: 0.0667
# EPOCH : 004/100 | Loss : 0.2398, training_accuracy: 0.0500
# EPOCH : 004/100 | Loss : 0.2763, training_accuracy: 0.0400
# EPOCH : 004/100 | Loss : 0.1966, training_accuracy: 0.0333
# EPOCH : 005/100 | Loss : 0.1812, training_accuracy: 0.1000
# EPOCH : 005/100 | Loss : 0.1714, training_accuracy: 0.0500
# EPOCH : 005/100 | Loss : 0.2487, training_accuracy: 0.0333
# EPOCH : 005/100 | Loss : 0.1999, training_accuracy: 0.0500
# EPOCH : 005/100 | Loss : 0.1954, training_accuracy: 0.0600
# EPOCH : 005/100 | Loss : 0.2259, training_accuracy: 0.0667
# EPOCH : 006/100 | Loss : 0.2293, training_accuracy: 0.0000
# EPOCH : 006/100 | Loss : 0.1947, training_accuracy: 0.0500
# EPOCH : 006/100 | Loss : 0.2195, training_accuracy: 0.0667
# EPOCH : 006/100 | Loss : 0.2292, training_accuracy: 0.0500
# EPOCH : 006/100 | Loss : 0.2495, training_accuracy: 0.0600
# EPOCH : 006/100 | Loss : 0.1833, training_accuracy: 0.0500
# EPOCH : 007/100 | Loss : 0.2050, training_accuracy: 0.0000
# EPOCH : 007/100 | Loss : 0.1997, training_accuracy: 0.0500
# EPOCH : 007/100 | Loss : 0.2096, training_accuracy: 0.0333
# EPOCH : 007/100 | Loss : 0.1763, training_accuracy: 0.0250
# EPOCH : 007/100 | Loss : 0.2432, training_accuracy: 0.0200
# EPOCH : 007/100 | Loss : 0.2250, training_accuracy: 0.0333
# EPOCH : 008/100 | Loss : 0.2337, training_accuracy: 0.0000
# EPOCH : 008/100 | Loss : 0.2020, training_accuracy: 0.0500
# EPOCH : 008/100 | Loss : 0.1664, training_accuracy: 0.0333
# EPOCH : 008/100 | Loss : 0.1714, training_accuracy: 0.1000
# EPOCH : 008/100 | Loss : 0.2082, training_accuracy: 0.1000
# EPOCH : 008/100 | Loss : 0.2084, training_accuracy: 0.1000
# EPOCH : 009/100 | Loss : 0.1886, training_accuracy: 0.2000
# EPOCH : 009/100 | Loss : 0.2308, training_accuracy: 0.1000
# EPOCH : 009/100 | Loss : 0.2146, training_accuracy: 0.0667
# EPOCH : 009/100 | Loss : 0.2289, training_accuracy: 0.0750
# EPOCH : 009/100 | Loss : 0.2045, training_accuracy: 0.0600
# EPOCH : 009/100 | Loss : 0.2018, training_accuracy: 0.0667
# EPOCH : 010/100 | Loss : 0.1702, training_accuracy: 0.1000
# EPOCH : 010/100 | Loss : 0.1722, training_accuracy: 0.1000
# EPOCH : 010/100 | Loss : 0.1654, training_accuracy: 0.0667
# EPOCH : 010/100 | Loss : 0.1854, training_accuracy: 0.0750
# EPOCH : 010/100 | Loss : 0.1551, training_accuracy: 0.1200
# EPOCH : 010/100 | Loss : 0.1674, training_accuracy: 0.1333
# EPOCH : 011/100 | Loss : 0.1732, training_accuracy: 0.1000
# EPOCH : 011/100 | Loss : 0.2022, training_accuracy: 0.1000
# EPOCH : 011/100 | Loss : 0.1638, training_accuracy: 0.1333
# EPOCH : 011/100 | Loss : 0.2470, training_accuracy: 0.1000
# EPOCH : 011/100 | Loss : 0.1750, training_accuracy: 0.1000
# EPOCH : 011/100 | Loss : 0.1756, training_accuracy: 0.1000
# EPOCH : 012/100 | Loss : 0.1592, training_accuracy: 0.1000
# EPOCH : 012/100 | Loss : 0.1481, training_accuracy: 0.1000
# EPOCH : 012/100 | Loss : 0.2760, training_accuracy: 0.1000
# EPOCH : 012/100 | Loss : 0.1934, training_accuracy: 0.1000
# EPOCH : 012/100 | Loss : 0.2359, training_accuracy: 0.1000
# EPOCH : 012/100 | Loss : 0.1700, training_accuracy: 0.0833
# EPOCH : 013/100 | Loss : 0.1946, training_accuracy: 0.0000
# EPOCH : 013/100 | Loss : 0.2173, training_accuracy: 0.0000
# EPOCH : 013/100 | Loss : 0.2150, training_accuracy: 0.0000
# EPOCH : 013/100 | Loss : 0.1504, training_accuracy: 0.1000
# EPOCH : 013/100 | Loss : 0.1535, training_accuracy: 0.1800
# EPOCH : 013/100 | Loss : 0.2229, training_accuracy: 0.1500
# EPOCH : 014/100 | Loss : 0.2292, training_accuracy: 0.1000
# EPOCH : 014/100 | Loss : 0.1927, training_accuracy: 0.0500
# EPOCH : 014/100 | Loss : 0.1810, training_accuracy: 0.0667
# EPOCH : 014/100 | Loss : 0.2050, training_accuracy: 0.0750
# EPOCH : 014/100 | Loss : 0.1866, training_accuracy: 0.1400
# EPOCH : 014/100 | Loss : 0.1985, training_accuracy: 0.1500
# EPOCH : 015/100 | Loss : 0.2803, training_accuracy: 0.1000
# EPOCH : 015/100 | Loss : 0.2838, training_accuracy: 0.0500
# EPOCH : 015/100 | Loss : 0.2157, training_accuracy: 0.0667
# EPOCH : 015/100 | Loss : 0.1710, training_accuracy: 0.1000
# EPOCH : 015/100 | Loss : 0.1474, training_accuracy: 0.1200
# EPOCH : 015/100 | Loss : 0.1914, training_accuracy: 0.1167
# EPOCH : 016/100 | Loss : 0.1584, training_accuracy: 0.1000
# EPOCH : 016/100 | Loss : 0.1673, training_accuracy: 0.1000
# EPOCH : 016/100 | Loss : 0.1376, training_accuracy: 0.2333
# EPOCH : 016/100 | Loss : 0.1866, training_accuracy: 0.1750
# EPOCH : 016/100 | Loss : 0.2312, training_accuracy: 0.1400
# EPOCH : 016/100 | Loss : 0.1858, training_accuracy: 0.1333
# EPOCH : 017/100 | Loss : 0.1867, training_accuracy: 0.0000
# EPOCH : 017/100 | Loss : 0.2344, training_accuracy: 0.0000
# EPOCH : 017/100 | Loss : 0.2090, training_accuracy: 0.0333
# EPOCH : 017/100 | Loss : 0.1616, training_accuracy: 0.0250
# EPOCH : 017/100 | Loss : 0.1981, training_accuracy: 0.0400
# EPOCH : 017/100 | Loss : 0.1370, training_accuracy: 0.1000
# EPOCH : 018/100 | Loss : 0.1598, training_accuracy: 0.3000
# EPOCH : 018/100 | Loss : 0.1624, training_accuracy: 0.3000
# EPOCH : 018/100 | Loss : 0.1777, training_accuracy: 0.2000
# EPOCH : 018/100 | Loss : 0.1865, training_accuracy: 0.1750
# EPOCH : 018/100 | Loss : 0.1958, training_accuracy: 0.1600
# EPOCH : 018/100 | Loss : 0.1677, training_accuracy: 0.1500
# EPOCH : 019/100 | Loss : 0.2018, training_accuracy: 0.1000
# EPOCH : 019/100 | Loss : 0.1488, training_accuracy: 0.1500
# EPOCH : 019/100 | Loss : 0.1608, training_accuracy: 0.1333
# EPOCH : 019/100 | Loss : 0.1810, training_accuracy: 0.1500
# EPOCH : 019/100 | Loss : 0.1656, training_accuracy: 0.1200
# EPOCH : 019/100 | Loss : 0.1719, training_accuracy: 0.1167
# EPOCH : 020/100 | Loss : 0.1764, training_accuracy: 0.2000
# EPOCH : 020/100 | Loss : 0.1536, training_accuracy: 0.2500
# EPOCH : 020/100 | Loss : 0.1644, training_accuracy: 0.2000
# EPOCH : 020/100 | Loss : 0.1352, training_accuracy: 0.1750
# EPOCH : 020/100 | Loss : 0.1429, training_accuracy: 0.2400
# EPOCH : 020/100 | Loss : 0.1824, training_accuracy: 0.2167
# EPOCH : 021/100 | Loss : 0.1572, training_accuracy: 0.4000
# EPOCH : 021/100 | Loss : 0.2033, training_accuracy: 0.2000
# EPOCH : 021/100 | Loss : 0.1622, training_accuracy: 0.1667
# EPOCH : 021/100 | Loss : 0.1932, training_accuracy: 0.1500
# EPOCH : 021/100 | Loss : 0.1890, training_accuracy: 0.1600
# EPOCH : 021/100 | Loss : 0.1740, training_accuracy: 0.1500
# EPOCH : 022/100 | Loss : 0.1808, training_accuracy: 0.1000
# EPOCH : 022/100 | Loss : 0.1455, training_accuracy: 0.2500
# EPOCH : 022/100 | Loss : 0.1777, training_accuracy: 0.2333
# EPOCH : 022/100 | Loss : 0.2089, training_accuracy: 0.2000
# EPOCH : 022/100 | Loss : 0.1777, training_accuracy: 0.2200
# EPOCH : 022/100 | Loss : 0.1673, training_accuracy: 0.2167
# EPOCH : 023/100 | Loss : 0.1883, training_accuracy: 0.1000
# EPOCH : 023/100 | Loss : 0.2041, training_accuracy: 0.0500
# EPOCH : 023/100 | Loss : 0.2230, training_accuracy: 0.0333
# EPOCH : 023/100 | Loss : 0.1513, training_accuracy: 0.1000
# EPOCH : 023/100 | Loss : 0.1718, training_accuracy: 0.1200
# EPOCH : 023/100 | Loss : 0.1685, training_accuracy: 0.1500
# EPOCH : 024/100 | Loss : 0.1737, training_accuracy: 0.1000
# EPOCH : 024/100 | Loss : 0.1676, training_accuracy: 0.1500
# EPOCH : 024/100 | Loss : 0.1538, training_accuracy: 0.1333
# EPOCH : 024/100 | Loss : 0.2032, training_accuracy: 0.1000
# EPOCH : 024/100 | Loss : 0.2221, training_accuracy: 0.0800
# EPOCH : 024/100 | Loss : 0.2573, training_accuracy: 0.0833
# EPOCH : 025/100 | Loss : 0.2276, training_accuracy: 0.1000
# EPOCH : 025/100 | Loss : 0.1338, training_accuracy: 0.2500
# EPOCH : 025/100 | Loss : 0.1689, training_accuracy: 0.2000
# EPOCH : 025/100 | Loss : 0.2639, training_accuracy: 0.2000
# EPOCH : 025/100 | Loss : 0.1851, training_accuracy: 0.2200
# EPOCH : 025/100 | Loss : 0.1568, training_accuracy: 0.2333
# EPOCH : 026/100 | Loss : 0.1895, training_accuracy: 0.1000
# EPOCH : 026/100 | Loss : 0.1769, training_accuracy: 0.2500
# EPOCH : 026/100 | Loss : 0.2149, training_accuracy: 0.2333
# EPOCH : 026/100 | Loss : 0.1622, training_accuracy: 0.2750
# EPOCH : 026/100 | Loss : 0.1564, training_accuracy: 0.2600
# EPOCH : 026/100 | Loss : 0.1754, training_accuracy: 0.2500
# EPOCH : 027/100 | Loss : 0.2037, training_accuracy: 0.3000
# EPOCH : 027/100 | Loss : 0.3105, training_accuracy: 0.1500
# EPOCH : 027/100 | Loss : 0.1521, training_accuracy: 0.1333
# EPOCH : 027/100 | Loss : 0.1774, training_accuracy: 0.1750
# EPOCH : 027/100 | Loss : 0.1371, training_accuracy: 0.1800
# EPOCH : 027/100 | Loss : 0.1793, training_accuracy: 0.1833
# EPOCH : 028/100 | Loss : 0.1507, training_accuracy: 0.2000
# EPOCH : 028/100 | Loss : 0.1994, training_accuracy: 0.1500
# EPOCH : 028/100 | Loss : 0.1289, training_accuracy: 0.1333
# EPOCH : 028/100 | Loss : 0.1274, training_accuracy: 0.1750
# EPOCH : 028/100 | Loss : 0.1476, training_accuracy: 0.2000
# EPOCH : 028/100 | Loss : 0.1456, training_accuracy: 0.2333
# EPOCH : 029/100 | Loss : 0.1347, training_accuracy: 0.3000
# EPOCH : 029/100 | Loss : 0.1508, training_accuracy: 0.2500
# EPOCH : 029/100 | Loss : 0.1605, training_accuracy: 0.2667
# EPOCH : 029/100 | Loss : 0.1872, training_accuracy: 0.2250
# EPOCH : 029/100 | Loss : 0.1901, training_accuracy: 0.2200
# EPOCH : 029/100 | Loss : 0.1249, training_accuracy: 0.2500
# EPOCH : 030/100 | Loss : 0.1032, training_accuracy: 0.3000
# EPOCH : 030/100 | Loss : 0.1572, training_accuracy: 0.2500
# EPOCH : 030/100 | Loss : 0.1645, training_accuracy: 0.2000
# EPOCH : 030/100 | Loss : 0.1198, training_accuracy: 0.2250
# EPOCH : 030/100 | Loss : 0.1605, training_accuracy: 0.2200
# EPOCH : 030/100 | Loss : 0.2010, training_accuracy: 0.2167
# EPOCH : 031/100 | Loss : 0.1751, training_accuracy: 0.2000
# EPOCH : 031/100 | Loss : 0.1590, training_accuracy: 0.3000
# EPOCH : 031/100 | Loss : 0.1247, training_accuracy: 0.3000
# EPOCH : 031/100 | Loss : 0.1440, training_accuracy: 0.3250
# EPOCH : 031/100 | Loss : 0.1460, training_accuracy: 0.3400
# EPOCH : 031/100 | Loss : 0.1745, training_accuracy: 0.3000
# EPOCH : 032/100 | Loss : 0.1605, training_accuracy: 0.2000
# EPOCH : 032/100 | Loss : 0.0996, training_accuracy: 0.4500
# EPOCH : 032/100 | Loss : 0.1810, training_accuracy: 0.3667
# EPOCH : 032/100 | Loss : 0.1757, training_accuracy: 0.3750
# EPOCH : 032/100 | Loss : 0.1282, training_accuracy: 0.3600
# EPOCH : 032/100 | Loss : 0.1328, training_accuracy: 0.3667
# EPOCH : 033/100 | Loss : 0.1309, training_accuracy: 0.3000
# EPOCH : 033/100 | Loss : 0.1690, training_accuracy: 0.2000
# EPOCH : 033/100 | Loss : 0.1730, training_accuracy: 0.1667
# EPOCH : 033/100 | Loss : 0.1692, training_accuracy: 0.1750
# EPOCH : 033/100 | Loss : 0.1109, training_accuracy: 0.2000
# EPOCH : 033/100 | Loss : 0.1602, training_accuracy: 0.2000
# EPOCH : 034/100 | Loss : 0.1426, training_accuracy: 0.2000
# EPOCH : 034/100 | Loss : 0.2211, training_accuracy: 0.2500
# EPOCH : 034/100 | Loss : 0.1225, training_accuracy: 0.2667
# EPOCH : 034/100 | Loss : 0.1377, training_accuracy: 0.2750
# EPOCH : 034/100 | Loss : 0.1159, training_accuracy: 0.3000
# EPOCH : 034/100 | Loss : 0.1452, training_accuracy: 0.3500
# EPOCH : 035/100 | Loss : 0.1295, training_accuracy: 0.2000
# EPOCH : 035/100 | Loss : 0.1268, training_accuracy: 0.3000
# EPOCH : 035/100 | Loss : 0.1839, training_accuracy: 0.2000
# EPOCH : 035/100 | Loss : 0.1463, training_accuracy: 0.2000
# EPOCH : 035/100 | Loss : 0.2257, training_accuracy: 0.1600
# EPOCH : 035/100 | Loss : 0.1251, training_accuracy: 0.2000
# EPOCH : 036/100 | Loss : 0.1676, training_accuracy: 0.1000
# EPOCH : 036/100 | Loss : 0.1555, training_accuracy: 0.2000
# EPOCH : 036/100 | Loss : 0.0842, training_accuracy: 0.3000
# EPOCH : 036/100 | Loss : 0.1224, training_accuracy: 0.2750
# EPOCH : 036/100 | Loss : 0.1738, training_accuracy: 0.2800
# EPOCH : 036/100 | Loss : 0.1298, training_accuracy: 0.3167
# EPOCH : 037/100 | Loss : 0.2112, training_accuracy: 0.2000
# EPOCH : 037/100 | Loss : 0.2138, training_accuracy: 0.2000
# EPOCH : 037/100 | Loss : 0.0992, training_accuracy: 0.3000
# EPOCH : 037/100 | Loss : 0.1325, training_accuracy: 0.3500
# EPOCH : 037/100 | Loss : 0.1156, training_accuracy: 0.3400
# EPOCH : 037/100 | Loss : 0.1443, training_accuracy: 0.3000
# EPOCH : 038/100 | Loss : 0.1402, training_accuracy: 0.2000
# EPOCH : 038/100 | Loss : 0.0903, training_accuracy: 0.3500
# EPOCH : 038/100 | Loss : 0.2032, training_accuracy: 0.2333
# EPOCH : 038/100 | Loss : 0.1038, training_accuracy: 0.2750
# EPOCH : 038/100 | Loss : 0.1276, training_accuracy: 0.2600
# EPOCH : 038/100 | Loss : 0.1671, training_accuracy: 0.2500
# EPOCH : 039/100 | Loss : 0.1969, training_accuracy: 0.1000
# EPOCH : 039/100 | Loss : 0.1697, training_accuracy: 0.1500
# EPOCH : 039/100 | Loss : 0.1825, training_accuracy: 0.1333
# EPOCH : 039/100 | Loss : 0.0879, training_accuracy: 0.2250
# EPOCH : 039/100 | Loss : 0.1304, training_accuracy: 0.2200
# EPOCH : 039/100 | Loss : 0.1240, training_accuracy: 0.2333
# EPOCH : 040/100 | Loss : 0.1057, training_accuracy: 0.3000
# EPOCH : 040/100 | Loss : 0.1577, training_accuracy: 0.2000
# EPOCH : 040/100 | Loss : 0.1967, training_accuracy: 0.2333
# EPOCH : 040/100 | Loss : 0.1588, training_accuracy: 0.2500
# EPOCH : 040/100 | Loss : 0.1427, training_accuracy: 0.2800
# EPOCH : 040/100 | Loss : 0.1274, training_accuracy: 0.2667
# EPOCH : 041/100 | Loss : 0.1023, training_accuracy: 0.4000
# EPOCH : 041/100 | Loss : 0.0799, training_accuracy: 0.3500
# EPOCH : 041/100 | Loss : 0.1804, training_accuracy: 0.2667
# EPOCH : 041/100 | Loss : 0.1458, training_accuracy: 0.2500
# EPOCH : 041/100 | Loss : 0.1222, training_accuracy: 0.2800
# EPOCH : 041/100 | Loss : 0.1566, training_accuracy: 0.2667
# EPOCH : 042/100 | Loss : 0.0643, training_accuracy: 0.7000
# EPOCH : 042/100 | Loss : 0.0928, training_accuracy: 0.5000
# EPOCH : 042/100 | Loss : 0.1233, training_accuracy: 0.4333
# EPOCH : 042/100 | Loss : 0.0385, training_accuracy: 0.5500
# EPOCH : 042/100 | Loss : 0.1673, training_accuracy: 0.4800
# EPOCH : 042/100 | Loss : 0.1448, training_accuracy: 0.4167
# EPOCH : 043/100 | Loss : 0.1080, training_accuracy: 0.3000
# EPOCH : 043/100 | Loss : 0.1251, training_accuracy: 0.3500
# EPOCH : 043/100 | Loss : 0.1120, training_accuracy: 0.3333
# EPOCH : 043/100 | Loss : 0.1147, training_accuracy: 0.3750
# EPOCH : 043/100 | Loss : 0.1087, training_accuracy: 0.3600
# EPOCH : 043/100 | Loss : 0.1817, training_accuracy: 0.3333
# EPOCH : 044/100 | Loss : 0.1067, training_accuracy: 0.3000
# EPOCH : 044/100 | Loss : 0.1382, training_accuracy: 0.3000
# EPOCH : 044/100 | Loss : 0.1201, training_accuracy: 0.3333
# EPOCH : 044/100 | Loss : 0.1190, training_accuracy: 0.3000
# EPOCH : 044/100 | Loss : 0.1114, training_accuracy: 0.3000
# EPOCH : 044/100 | Loss : 0.1107, training_accuracy: 0.2833
# EPOCH : 045/100 | Loss : 0.1218, training_accuracy: 0.2000
# EPOCH : 045/100 | Loss : 0.1726, training_accuracy: 0.1500
# EPOCH : 045/100 | Loss : 0.1442, training_accuracy: 0.2333
# EPOCH : 045/100 | Loss : 0.1219, training_accuracy: 0.2750
# EPOCH : 045/100 | Loss : 0.1764, training_accuracy: 0.2600
# EPOCH : 045/100 | Loss : 0.1231, training_accuracy: 0.3000
# EPOCH : 046/100 | Loss : 0.0677, training_accuracy: 0.6000
# EPOCH : 046/100 | Loss : 0.0953, training_accuracy: 0.5000
# EPOCH : 046/100 | Loss : 0.1237, training_accuracy: 0.4667
# EPOCH : 046/100 | Loss : 0.0659, training_accuracy: 0.5000
# EPOCH : 046/100 | Loss : 0.1014, training_accuracy: 0.5000
# EPOCH : 046/100 | Loss : 0.1993, training_accuracy: 0.4667
# EPOCH : 047/100 | Loss : 0.1153, training_accuracy: 0.1000
# EPOCH : 047/100 | Loss : 0.1024, training_accuracy: 0.3000
# EPOCH : 047/100 | Loss : 0.1326, training_accuracy: 0.3000
# EPOCH : 047/100 | Loss : 0.1446, training_accuracy: 0.2500
# EPOCH : 047/100 | Loss : 0.1218, training_accuracy: 0.2600
# EPOCH : 047/100 | Loss : 0.1635, training_accuracy: 0.2500
# EPOCH : 048/100 | Loss : 0.0457, training_accuracy: 0.6000
# EPOCH : 048/100 | Loss : 0.1361, training_accuracy: 0.4500
# EPOCH : 048/100 | Loss : 0.1727, training_accuracy: 0.3667
# EPOCH : 048/100 | Loss : 0.1341, training_accuracy: 0.3500
# EPOCH : 048/100 | Loss : 0.1029, training_accuracy: 0.4000
# EPOCH : 048/100 | Loss : 0.1243, training_accuracy: 0.3833
# EPOCH : 049/100 | Loss : 0.0923, training_accuracy: 0.4000
# EPOCH : 049/100 | Loss : 0.1019, training_accuracy: 0.3500
# EPOCH : 049/100 | Loss : 0.1004, training_accuracy: 0.4000
# EPOCH : 049/100 | Loss : 0.1349, training_accuracy: 0.4250
# EPOCH : 049/100 | Loss : 0.1126, training_accuracy: 0.4200
# EPOCH : 049/100 | Loss : 0.0966, training_accuracy: 0.4000
# EPOCH : 050/100 | Loss : 0.0972, training_accuracy: 0.2000
# EPOCH : 050/100 | Loss : 0.0875, training_accuracy: 0.3500
# EPOCH : 050/100 | Loss : 0.1053, training_accuracy: 0.4000
# EPOCH : 050/100 | Loss : 0.0931, training_accuracy: 0.4000
# EPOCH : 050/100 | Loss : 0.0801, training_accuracy: 0.4200
# EPOCH : 050/100 | Loss : 0.0706, training_accuracy: 0.4667
# EPOCH : 051/100 | Loss : 0.0991, training_accuracy: 0.4000
# EPOCH : 051/100 | Loss : 0.1627, training_accuracy: 0.3500
# EPOCH : 051/100 | Loss : 0.0800, training_accuracy: 0.4000
# EPOCH : 051/100 | Loss : 0.0872, training_accuracy: 0.4750
# EPOCH : 051/100 | Loss : 0.0829, training_accuracy: 0.4600
# EPOCH : 051/100 | Loss : 0.1582, training_accuracy: 0.4333
# EPOCH : 052/100 | Loss : 0.1322, training_accuracy: 0.3000
# EPOCH : 052/100 | Loss : 0.0961, training_accuracy: 0.4000
# EPOCH : 052/100 | Loss : 0.1084, training_accuracy: 0.3667
# EPOCH : 052/100 | Loss : 0.0991, training_accuracy: 0.4000
# EPOCH : 052/100 | Loss : 0.1452, training_accuracy: 0.3600
# EPOCH : 052/100 | Loss : 0.1395, training_accuracy: 0.3167
# EPOCH : 053/100 | Loss : 0.0558, training_accuracy: 0.6000
# EPOCH : 053/100 | Loss : 0.0594, training_accuracy: 0.6000
# EPOCH : 053/100 | Loss : 0.1344, training_accuracy: 0.4667
# EPOCH : 053/100 | Loss : 0.0642, training_accuracy: 0.5250
# EPOCH : 053/100 | Loss : 0.0876, training_accuracy: 0.5200
# EPOCH : 053/100 | Loss : 0.1086, training_accuracy: 0.4500
# EPOCH : 054/100 | Loss : 0.0608, training_accuracy: 0.4000
# EPOCH : 054/100 | Loss : 0.1358, training_accuracy: 0.3000
# EPOCH : 054/100 | Loss : 0.0961, training_accuracy: 0.3333
# EPOCH : 054/100 | Loss : 0.1077, training_accuracy: 0.3500
# EPOCH : 054/100 | Loss : 0.1272, training_accuracy: 0.3600
# EPOCH : 054/100 | Loss : 0.0628, training_accuracy: 0.4167
# EPOCH : 055/100 | Loss : 0.1315, training_accuracy: 0.4000
# EPOCH : 055/100 | Loss : 0.0863, training_accuracy: 0.4000
# EPOCH : 055/100 | Loss : 0.0663, training_accuracy: 0.5000
# EPOCH : 055/100 | Loss : 0.0765, training_accuracy: 0.5000
# EPOCH : 055/100 | Loss : 0.0500, training_accuracy: 0.5800
# EPOCH : 055/100 | Loss : 0.1303, training_accuracy: 0.5333
# EPOCH : 056/100 | Loss : 0.0652, training_accuracy: 0.6000
# EPOCH : 056/100 | Loss : 0.1267, training_accuracy: 0.5500
# EPOCH : 056/100 | Loss : 0.0707, training_accuracy: 0.6000
# EPOCH : 056/100 | Loss : 0.0849, training_accuracy: 0.5250
# EPOCH : 056/100 | Loss : 0.0720, training_accuracy: 0.5200
# EPOCH : 056/100 | Loss : 0.0650, training_accuracy: 0.5167
# EPOCH : 057/100 | Loss : 0.1389, training_accuracy: 0.3000
# EPOCH : 057/100 | Loss : 0.0899, training_accuracy: 0.3500
# EPOCH : 057/100 | Loss : 0.1196, training_accuracy: 0.4000
# EPOCH : 057/100 | Loss : 0.0850, training_accuracy: 0.4500
# EPOCH : 057/100 | Loss : 0.0910, training_accuracy: 0.4600
# EPOCH : 057/100 | Loss : 0.1146, training_accuracy: 0.4667
# EPOCH : 058/100 | Loss : 0.0829, training_accuracy: 0.5000
# EPOCH : 058/100 | Loss : 0.1134, training_accuracy: 0.4500
# EPOCH : 058/100 | Loss : 0.0437, training_accuracy: 0.5667
# EPOCH : 058/100 | Loss : 0.0679, training_accuracy: 0.6000
# EPOCH : 058/100 | Loss : 0.1095, training_accuracy: 0.5200
# EPOCH : 058/100 | Loss : 0.1312, training_accuracy: 0.5333
# EPOCH : 059/100 | Loss : 0.0717, training_accuracy: 0.5000
# EPOCH : 059/100 | Loss : 0.1111, training_accuracy: 0.5000
# EPOCH : 059/100 | Loss : 0.0523, training_accuracy: 0.5667
# EPOCH : 059/100 | Loss : 0.0725, training_accuracy: 0.5750
# EPOCH : 059/100 | Loss : 0.1484, training_accuracy: 0.5200
# EPOCH : 059/100 | Loss : 0.0697, training_accuracy: 0.5500
# EPOCH : 060/100 | Loss : 0.0946, training_accuracy: 0.5000
# EPOCH : 060/100 | Loss : 0.1071, training_accuracy: 0.5000
# EPOCH : 060/100 | Loss : 0.0916, training_accuracy: 0.5333
# EPOCH : 060/100 | Loss : 0.1043, training_accuracy: 0.5250
# EPOCH : 060/100 | Loss : 0.0688, training_accuracy: 0.5200
# EPOCH : 060/100 | Loss : 0.1411, training_accuracy: 0.5167
# EPOCH : 061/100 | Loss : 0.0679, training_accuracy: 0.5000
# EPOCH : 061/100 | Loss : 0.0994, training_accuracy: 0.5000
# EPOCH : 061/100 | Loss : 0.0751, training_accuracy: 0.5000
# EPOCH : 061/100 | Loss : 0.0440, training_accuracy: 0.5750
# EPOCH : 061/100 | Loss : 0.1109, training_accuracy: 0.5600
# EPOCH : 061/100 | Loss : 0.0831, training_accuracy: 0.5667
# EPOCH : 062/100 | Loss : 0.0815, training_accuracy: 0.6000
# EPOCH : 062/100 | Loss : 0.0307, training_accuracy: 0.7000
# EPOCH : 062/100 | Loss : 0.1037, training_accuracy: 0.5667
# EPOCH : 062/100 | Loss : 0.1071, training_accuracy: 0.5500
# EPOCH : 062/100 | Loss : 0.0930, training_accuracy: 0.5400
# EPOCH : 062/100 | Loss : 0.0642, training_accuracy: 0.5667
# EPOCH : 063/100 | Loss : 0.0898, training_accuracy: 0.7000
# EPOCH : 063/100 | Loss : 0.0212, training_accuracy: 0.8000
# EPOCH : 063/100 | Loss : 0.1165, training_accuracy: 0.7000
# EPOCH : 063/100 | Loss : 0.0748, training_accuracy: 0.6500
# EPOCH : 063/100 | Loss : 0.1007, training_accuracy: 0.6000
# EPOCH : 063/100 | Loss : 0.0933, training_accuracy: 0.5667
# EPOCH : 064/100 | Loss : 0.0290, training_accuracy: 1.0000
# EPOCH : 064/100 | Loss : 0.0619, training_accuracy: 0.8000
# EPOCH : 064/100 | Loss : 0.0396, training_accuracy: 0.8000
# EPOCH : 064/100 | Loss : 0.0640, training_accuracy: 0.7750
# EPOCH : 064/100 | Loss : 0.1215, training_accuracy: 0.7000
# EPOCH : 064/100 | Loss : 0.0666, training_accuracy: 0.6667
# EPOCH : 065/100 | Loss : 0.0540, training_accuracy: 0.9000
# EPOCH : 065/100 | Loss : 0.0611, training_accuracy: 0.8000
# EPOCH : 065/100 | Loss : 0.1067, training_accuracy: 0.6667
# EPOCH : 065/100 | Loss : 0.0540, training_accuracy: 0.6500
# EPOCH : 065/100 | Loss : 0.0697, training_accuracy: 0.6400
# EPOCH : 065/100 | Loss : 0.0482, training_accuracy: 0.6500
# EPOCH : 066/100 | Loss : 0.0637, training_accuracy: 0.7000
# EPOCH : 066/100 | Loss : 0.0487, training_accuracy: 0.7000
# EPOCH : 066/100 | Loss : 0.0886, training_accuracy: 0.6333
# EPOCH : 066/100 | Loss : 0.0803, training_accuracy: 0.6250
# EPOCH : 066/100 | Loss : 0.0759, training_accuracy: 0.6200
# EPOCH : 066/100 | Loss : 0.0539, training_accuracy: 0.6333
# EPOCH : 067/100 | Loss : 0.0488, training_accuracy: 0.9000
# EPOCH : 067/100 | Loss : 0.0786, training_accuracy: 0.7000
# EPOCH : 067/100 | Loss : 0.0824, training_accuracy: 0.7000
# EPOCH : 067/100 | Loss : 0.0540, training_accuracy: 0.6750
# EPOCH : 067/100 | Loss : 0.1279, training_accuracy: 0.6800
# EPOCH : 067/100 | Loss : 0.0877, training_accuracy: 0.6833
# EPOCH : 068/100 | Loss : 0.0358, training_accuracy: 0.8000
# EPOCH : 068/100 | Loss : 0.0307, training_accuracy: 0.8000
# EPOCH : 068/100 | Loss : 0.0464, training_accuracy: 0.8000
# EPOCH : 068/100 | Loss : 0.0430, training_accuracy: 0.8250
# EPOCH : 068/100 | Loss : 0.0450, training_accuracy: 0.8000
# EPOCH : 068/100 | Loss : 0.0255, training_accuracy: 0.8000
# EPOCH : 069/100 | Loss : 0.0548, training_accuracy: 0.7000
# EPOCH : 069/100 | Loss : 0.0328, training_accuracy: 0.8000
# EPOCH : 069/100 | Loss : 0.0451, training_accuracy: 0.8000
# EPOCH : 069/100 | Loss : 0.0555, training_accuracy: 0.8000
# EPOCH : 069/100 | Loss : 0.0610, training_accuracy: 0.7800
# EPOCH : 069/100 | Loss : 0.0217, training_accuracy: 0.8000
# EPOCH : 070/100 | Loss : 0.0504, training_accuracy: 0.8000
# EPOCH : 070/100 | Loss : 0.1095, training_accuracy: 0.6000
# EPOCH : 070/100 | Loss : 0.0356, training_accuracy: 0.6333
# EPOCH : 070/100 | Loss : 0.0529, training_accuracy: 0.6750
# EPOCH : 070/100 | Loss : 0.0557, training_accuracy: 0.6600
# EPOCH : 070/100 | Loss : 0.1152, training_accuracy: 0.6167
# EPOCH : 071/100 | Loss : 0.0259, training_accuracy: 0.9000
# EPOCH : 071/100 | Loss : 0.0354, training_accuracy: 0.8500
# EPOCH : 071/100 | Loss : 0.1132, training_accuracy: 0.7000
# EPOCH : 071/100 | Loss : 0.0416, training_accuracy: 0.7000
# EPOCH : 071/100 | Loss : 0.0424, training_accuracy: 0.6800
# EPOCH : 071/100 | Loss : 0.0619, training_accuracy: 0.6500
# EPOCH : 072/100 | Loss : 0.0368, training_accuracy: 0.8000
# EPOCH : 072/100 | Loss : 0.0567, training_accuracy: 0.7500
# EPOCH : 072/100 | Loss : 0.0593, training_accuracy: 0.6667
# EPOCH : 072/100 | Loss : 0.0974, training_accuracy: 0.6250
# EPOCH : 072/100 | Loss : 0.0665, training_accuracy: 0.6200
# EPOCH : 072/100 | Loss : 0.0687, training_accuracy: 0.6167
# EPOCH : 073/100 | Loss : 0.0299, training_accuracy: 0.9000
# EPOCH : 073/100 | Loss : 0.0586, training_accuracy: 0.8500
# EPOCH : 073/100 | Loss : 0.0501, training_accuracy: 0.7667
# EPOCH : 073/100 | Loss : 0.0732, training_accuracy: 0.7250
# EPOCH : 073/100 | Loss : 0.0627, training_accuracy: 0.7000
# EPOCH : 073/100 | Loss : 0.0869, training_accuracy: 0.6833
# EPOCH : 074/100 | Loss : 0.0608, training_accuracy: 0.6000
# EPOCH : 074/100 | Loss : 0.0647, training_accuracy: 0.5500
# EPOCH : 074/100 | Loss : 0.0348, training_accuracy: 0.6333
# EPOCH : 074/100 | Loss : 0.0509, training_accuracy: 0.6000
# EPOCH : 074/100 | Loss : 0.0694, training_accuracy: 0.6000
# EPOCH : 074/100 | Loss : 0.0673, training_accuracy: 0.6167
# EPOCH : 075/100 | Loss : 0.0728, training_accuracy: 0.6000
# EPOCH : 075/100 | Loss : 0.0389, training_accuracy: 0.7000
# EPOCH : 075/100 | Loss : 0.0328, training_accuracy: 0.7333
# EPOCH : 075/100 | Loss : 0.0455, training_accuracy: 0.7500
# EPOCH : 075/100 | Loss : 0.0609, training_accuracy: 0.7400
# EPOCH : 075/100 | Loss : 0.0309, training_accuracy: 0.7500
# EPOCH : 076/100 | Loss : 0.0344, training_accuracy: 0.9000
# EPOCH : 076/100 | Loss : 0.0475, training_accuracy: 0.7500
# EPOCH : 076/100 | Loss : 0.0407, training_accuracy: 0.7333
# EPOCH : 076/100 | Loss : 0.0504, training_accuracy: 0.7250
# EPOCH : 076/100 | Loss : 0.0090, training_accuracy: 0.7800
# EPOCH : 076/100 | Loss : 0.1149, training_accuracy: 0.7333
# EPOCH : 077/100 | Loss : 0.0557, training_accuracy: 0.5000
# EPOCH : 077/100 | Loss : 0.0267, training_accuracy: 0.6500
# EPOCH : 077/100 | Loss : 0.0392, training_accuracy: 0.7000
# EPOCH : 077/100 | Loss : 0.0386, training_accuracy: 0.7250
# EPOCH : 077/100 | Loss : 0.0341, training_accuracy: 0.7200
# EPOCH : 077/100 | Loss : 0.0514, training_accuracy: 0.7000
# EPOCH : 078/100 | Loss : 0.0760, training_accuracy: 0.7000
# EPOCH : 078/100 | Loss : 0.0248, training_accuracy: 0.7500
# EPOCH : 078/100 | Loss : 0.0353, training_accuracy: 0.7333
# EPOCH : 078/100 | Loss : 0.0516, training_accuracy: 0.7000
# EPOCH : 078/100 | Loss : 0.1204, training_accuracy: 0.6400
# EPOCH : 078/100 | Loss : 0.1007, training_accuracy: 0.6167
# EPOCH : 079/100 | Loss : 0.0546, training_accuracy: 0.6000
# EPOCH : 079/100 | Loss : 0.0257, training_accuracy: 0.7000
# EPOCH : 079/100 | Loss : 0.0319, training_accuracy: 0.7000
# EPOCH : 079/100 | Loss : 0.0146, training_accuracy: 0.7750
# EPOCH : 079/100 | Loss : 0.0670, training_accuracy: 0.7600
# EPOCH : 079/100 | Loss : 0.0554, training_accuracy: 0.7667
# EPOCH : 080/100 | Loss : 0.0273, training_accuracy: 0.8000
# EPOCH : 080/100 | Loss : 0.0163, training_accuracy: 0.8500
# EPOCH : 080/100 | Loss : 0.0401, training_accuracy: 0.8000
# EPOCH : 080/100 | Loss : 0.0478, training_accuracy: 0.7500
# EPOCH : 080/100 | Loss : 0.0189, training_accuracy: 0.7800
# EPOCH : 080/100 | Loss : 0.0672, training_accuracy: 0.7667
# EPOCH : 081/100 | Loss : 0.0317, training_accuracy: 0.8000
# EPOCH : 081/100 | Loss : 0.0311, training_accuracy: 0.8500
# EPOCH : 081/100 | Loss : 0.0695, training_accuracy: 0.7667
# EPOCH : 081/100 | Loss : 0.0452, training_accuracy: 0.7750
# EPOCH : 081/100 | Loss : 0.0315, training_accuracy: 0.7800
# EPOCH : 081/100 | Loss : 0.0753, training_accuracy: 0.7333
# EPOCH : 082/100 | Loss : 0.0382, training_accuracy: 0.7000
# EPOCH : 082/100 | Loss : 0.0481, training_accuracy: 0.6500
# EPOCH : 082/100 | Loss : 0.0423, training_accuracy: 0.7000
# EPOCH : 082/100 | Loss : 0.0445, training_accuracy: 0.7000
# EPOCH : 082/100 | Loss : 0.0267, training_accuracy: 0.7400
# EPOCH : 082/100 | Loss : 0.0838, training_accuracy: 0.7167
# EPOCH : 083/100 | Loss : 0.0413, training_accuracy: 0.8000
# EPOCH : 083/100 | Loss : 0.0209, training_accuracy: 0.8500
# EPOCH : 083/100 | Loss : 0.0234, training_accuracy: 0.8667
# EPOCH : 083/100 | Loss : 0.0237, training_accuracy: 0.8500
# EPOCH : 083/100 | Loss : 0.0277, training_accuracy: 0.8600
# EPOCH : 083/100 | Loss : 0.0041, training_accuracy: 0.8833
# EPOCH : 084/100 | Loss : 0.0751, training_accuracy: 0.6000
# EPOCH : 084/100 | Loss : 0.0503, training_accuracy: 0.6500
# EPOCH : 084/100 | Loss : 0.0268, training_accuracy: 0.7000
# EPOCH : 084/100 | Loss : 0.0198, training_accuracy: 0.7500
# EPOCH : 084/100 | Loss : 0.0641, training_accuracy: 0.7000
# EPOCH : 084/100 | Loss : 0.0214, training_accuracy: 0.7333
# EPOCH : 085/100 | Loss : 0.0221, training_accuracy: 0.8000
# EPOCH : 085/100 | Loss : 0.0259, training_accuracy: 0.8000
# EPOCH : 085/100 | Loss : 0.0299, training_accuracy: 0.8333
# EPOCH : 085/100 | Loss : 0.0074, training_accuracy: 0.8750
# EPOCH : 085/100 | Loss : 0.0443, training_accuracy: 0.8600
# EPOCH : 085/100 | Loss : 0.0395, training_accuracy: 0.8500
# EPOCH : 086/100 | Loss : 0.0260, training_accuracy: 0.9000
# EPOCH : 086/100 | Loss : 0.0254, training_accuracy: 0.9000
# EPOCH : 086/100 | Loss : 0.0274, training_accuracy: 0.8333
# EPOCH : 086/100 | Loss : 0.0220, training_accuracy: 0.8500
# EPOCH : 086/100 | Loss : 0.0306, training_accuracy: 0.8400
# EPOCH : 086/100 | Loss : 0.0612, training_accuracy: 0.8000
# EPOCH : 087/100 | Loss : 0.0143, training_accuracy: 0.9000
# EPOCH : 087/100 | Loss : 0.0194, training_accuracy: 0.9000
# EPOCH : 087/100 | Loss : 0.0495, training_accuracy: 0.8333
# EPOCH : 087/100 | Loss : 0.0144, training_accuracy: 0.8500
# EPOCH : 087/100 | Loss : 0.0153, training_accuracy: 0.8600
# EPOCH : 087/100 | Loss : 0.0612, training_accuracy: 0.8333
# EPOCH : 088/100 | Loss : 0.0297, training_accuracy: 0.7000
# EPOCH : 088/100 | Loss : 0.0370, training_accuracy: 0.7000
# EPOCH : 088/100 | Loss : 0.0460, training_accuracy: 0.7667
# EPOCH : 088/100 | Loss : 0.0463, training_accuracy: 0.7500
# EPOCH : 088/100 | Loss : 0.0474, training_accuracy: 0.7400
# EPOCH : 088/100 | Loss : 0.0432, training_accuracy: 0.7000
# EPOCH : 089/100 | Loss : 0.0215, training_accuracy: 0.9000
# EPOCH : 089/100 | Loss : 0.0275, training_accuracy: 0.8500
# EPOCH : 089/100 | Loss : 0.0490, training_accuracy: 0.8333
# EPOCH : 089/100 | Loss : 0.0242, training_accuracy: 0.8250
# EPOCH : 089/100 | Loss : 0.0641, training_accuracy: 0.7800
# EPOCH : 089/100 | Loss : 0.0131, training_accuracy: 0.8167
# EPOCH : 090/100 | Loss : 0.0427, training_accuracy: 0.9000
# EPOCH : 090/100 | Loss : 0.0097, training_accuracy: 0.9000
# EPOCH : 090/100 | Loss : 0.0378, training_accuracy: 0.8667
# EPOCH : 090/100 | Loss : 0.0445, training_accuracy: 0.8250
# EPOCH : 090/100 | Loss : 0.1065, training_accuracy: 0.7400
# EPOCH : 090/100 | Loss : 0.0747, training_accuracy: 0.7167
# EPOCH : 091/100 | Loss : 0.0273, training_accuracy: 0.9000
# EPOCH : 091/100 | Loss : 0.0415, training_accuracy: 0.8500
# EPOCH : 091/100 | Loss : 0.0401, training_accuracy: 0.8000
# EPOCH : 091/100 | Loss : 0.0182, training_accuracy: 0.8250
# EPOCH : 091/100 | Loss : 0.0349, training_accuracy: 0.8400
# EPOCH : 091/100 | Loss : 0.0448, training_accuracy: 0.8167
# EPOCH : 092/100 | Loss : 0.0561, training_accuracy: 0.8000
# EPOCH : 092/100 | Loss : 0.0272, training_accuracy: 0.8000
# EPOCH : 092/100 | Loss : 0.0705, training_accuracy: 0.7333
# EPOCH : 092/100 | Loss : 0.0217, training_accuracy: 0.7750
# EPOCH : 092/100 | Loss : 0.0459, training_accuracy: 0.7400
# EPOCH : 092/100 | Loss : 0.0084, training_accuracy: 0.7667
# EPOCH : 093/100 | Loss : 0.0402, training_accuracy: 0.8000
# EPOCH : 093/100 | Loss : 0.0454, training_accuracy: 0.7500
# EPOCH : 093/100 | Loss : 0.0097, training_accuracy: 0.8333
# EPOCH : 093/100 | Loss : 0.0332, training_accuracy: 0.8000
# EPOCH : 093/100 | Loss : 0.0168, training_accuracy: 0.8200
# EPOCH : 093/100 | Loss : 0.0446, training_accuracy: 0.8000
# EPOCH : 094/100 | Loss : 0.0540, training_accuracy: 0.6000
# EPOCH : 094/100 | Loss : 0.0360, training_accuracy: 0.7000
# EPOCH : 094/100 | Loss : 0.0888, training_accuracy: 0.6667
# EPOCH : 094/100 | Loss : 0.0681, training_accuracy: 0.6750
# EPOCH : 094/100 | Loss : 0.0393, training_accuracy: 0.7000
# EPOCH : 094/100 | Loss : 0.0310, training_accuracy: 0.7000
# EPOCH : 095/100 | Loss : 0.0391, training_accuracy: 0.8000
# EPOCH : 095/100 | Loss : 0.0516, training_accuracy: 0.7000
# EPOCH : 095/100 | Loss : 0.0224, training_accuracy: 0.7667
# EPOCH : 095/100 | Loss : 0.0430, training_accuracy: 0.7500
# EPOCH : 095/100 | Loss : 0.0399, training_accuracy: 0.7600
# EPOCH : 095/100 | Loss : 0.0201, training_accuracy: 0.7833
# EPOCH : 096/100 | Loss : 0.0071, training_accuracy: 1.0000
# EPOCH : 096/100 | Loss : 0.0101, training_accuracy: 1.0000
# EPOCH : 096/100 | Loss : 0.0222, training_accuracy: 0.9333
# EPOCH : 096/100 | Loss : 0.0160, training_accuracy: 0.9250
# EPOCH : 096/100 | Loss : 0.0218, training_accuracy: 0.9000
# EPOCH : 096/100 | Loss : 0.0463, training_accuracy: 0.8833
# EPOCH : 097/100 | Loss : 0.0142, training_accuracy: 0.9000
# EPOCH : 097/100 | Loss : 0.0129, training_accuracy: 0.9000
# EPOCH : 097/100 | Loss : 0.0446, training_accuracy: 0.8333
# EPOCH : 097/100 | Loss : 0.0423, training_accuracy: 0.8000
# EPOCH : 097/100 | Loss : 0.0566, training_accuracy: 0.7800
# EPOCH : 097/100 | Loss : 0.0114, training_accuracy: 0.8167
# EPOCH : 098/100 | Loss : 0.0133, training_accuracy: 1.0000
# EPOCH : 098/100 | Loss : 0.0195, training_accuracy: 0.8500
# EPOCH : 098/100 | Loss : 0.0231, training_accuracy: 0.8333
# EPOCH : 098/100 | Loss : 0.0140, training_accuracy: 0.8500
# EPOCH : 098/100 | Loss : 0.0105, training_accuracy: 0.8600
# EPOCH : 098/100 | Loss : 0.0558, training_accuracy: 0.8167
# EPOCH : 099/100 | Loss : 0.0233, training_accuracy: 0.8000
# EPOCH : 099/100 | Loss : 0.0227, training_accuracy: 0.8500
# EPOCH : 099/100 | Loss : 0.0234, training_accuracy: 0.8000
# EPOCH : 099/100 | Loss : 0.0214, training_accuracy: 0.8250
# EPOCH : 099/100 | Loss : 0.0239, training_accuracy: 0.8400
# EPOCH : 099/100 | Loss : 0.0488, training_accuracy: 0.8333
# EPOCH : 100/100 | Loss : 0.0164, training_accuracy: 0.9000
# EPOCH : 100/100 | Loss : 0.0139, training_accuracy: 0.8500
# EPOCH : 100/100 | Loss : 0.0202, training_accuracy: 0.8667
# EPOCH : 100/100 | Loss : 0.0442, training_accuracy: 0.8250
# EPOCH : 100/100 | Loss : 0.0269, training_accuracy: 0.8000
# EPOCH : 100/100 | Loss : 0.0571, training_accuracy: 0.7833

# %%
params = model.parameters()
optimizer = torch.optim.SGD(params, lr= 0.01)
#optimizer =torch.optim.Adagrad(params, lr=0.01, lr_decay=0)
criterion = nn.BCELoss(reduction='mean')

# %%
EPOCH = 100
writer = SummaryWriter()
test_acc = []
for ep in range(1, EPOCH+1):
    test_count = 0
    accuracy = 0 
    acc = 0
    it_count = 0
    model.train()
    for it, (img, target) in enumerate(train_loader):
        
        img = img.to(Device)
        target = target.to(Device)

        optimizer.zero_grad()
        pred = model(img)
        loss = criterion(pred, target)
        loss.backward()
        optimizer.step()
        average_loss =  loss.item() 
        
        if it%100==0:
            pred = get_prediction(pred)
            acc += get_accuracy(pred, target)
            print('EPOCH : {:03d}/{:3d} | Loss : {:.4f}, training_accuracy: {:.4f}'.format(ep, EPOCH, average_loss, acc/(it_count+1)))
            #writer.add_scalars('training_loss', average_loss , it_count)
            it_count +=1
    
    #for it, (img, target)  in enumerate(val_loader):
    #    img = img.to(Device)
    #    target = target.to(Device)
    #    pred = model(img)
    #    pred = get_prediction(pred)
    #    accuracy += get_accuracy(pred, target)
    #    test_count += 1
    #accuracy /= test_count
    #test_acc.append(accuracy)
    #print('Test accuracy : {:.4f}'.format(accuracy))
    if (ep+1) == EPOCH:
        torch.save(model.state_dict(), './weights/Baseline_{}_{}.pt'.format(exper_name, 199))
# Out:
# EPOCH : 001/100 | Loss : 0.0170, training_accuracy: 0.9000
# EPOCH : 001/100 | Loss : 0.0130, training_accuracy: 0.9000
# EPOCH : 001/100 | Loss : 0.0225, training_accuracy: 0.8667
# EPOCH : 001/100 | Loss : 0.0052, training_accuracy: 0.9000
# EPOCH : 001/100 | Loss : 0.0112, training_accuracy: 0.9000
# EPOCH : 001/100 | Loss : 0.0143, training_accuracy: 0.8833
# EPOCH : 002/100 | Loss : 0.0379, training_accuracy: 0.9000
# EPOCH : 002/100 | Loss : 0.0253, training_accuracy: 0.8500
# EPOCH : 002/100 | Loss : 0.0252, training_accuracy: 0.8667
# EPOCH : 002/100 | Loss : 0.0217, training_accuracy: 0.8500
# EPOCH : 002/100 | Loss : 0.0136, training_accuracy: 0.8400
# EPOCH : 002/100 | Loss : 0.0254, training_accuracy: 0.8167
# EPOCH : 003/100 | Loss : 0.0090, training_accuracy: 0.9000
# EPOCH : 003/100 | Loss : 0.0111, training_accuracy: 0.9500
# EPOCH : 003/100 | Loss : 0.0175, training_accuracy: 0.9333
# EPOCH : 003/100 | Loss : 0.0259, training_accuracy: 0.9000
